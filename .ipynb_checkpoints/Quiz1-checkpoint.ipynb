# %% [markdown]
# # My First Data Science Notebook #
#
# Data Science is important because there is an immense ammount of data and numbers in today's world that need to be understood and easily communicated with the lay public. Misinformation is rampant and without people that understand the data, we would all be lost. Additionally, research is heavily reliant on the collection and analysis of data. Without a good understanding of data science, there would be no good analysis.

# %%
print("Hello, my name is Adedamola Adeyemi.\nData Science is exciting!")
# Out:
# Hello, my name is Adedamola Adeyemi.
# Data Science is exciting!

# %%
name=('Adedamola Adeyemi')
age=(19)
study_hours=(37.5)

# %%
print(name)
print(age)
print(study_hours)
# Out:
# Adedamola Adeyemi
# 19
# 37.5

# %%
print(name,age,study_hours)
# Out:
# Adedamola Adeyemi 19 37.5

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(study_hours)
# Out:
# float

# %%
int(study_hours)
# Out:
# 37

# %%
float(age)
# Out:
# 19.0
