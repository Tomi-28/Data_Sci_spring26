# %% [markdown]
# ## Write a Python program that:
#
# * Accepts three numbers from the user.
#
# * Finds the greatest number among the three.
#
# * Finds the smallest number among the three.
#
# * Calculates and displays the difference between the greatest and the smallest numbers.

# %%
## Q1: Your answer:
num1=8
num2=9
num3=10
difference=num3-num1
if num1>num3:
    if num1>num2:
        if num2>num3:
            print(f'{num2} is greater than {num3} and the difference is {difference}')
        else:
            print(f'{num3} is greater than {num2} and the difference is {difference}')
        print(f'{num1} is greater than {num3} and the difference is {difference}')
    else:
        print(f'{num3} is greater than {num1} and the difference is {difference}')
    print(f'{num1} is greater than {num3} and the difference is {difference}')
else:
    print(f'{num3} is greater than {num1} and the difference is {difference}')
# Out:
# 10 is greater than 8 and the difference is 2
