# %%
x=3

# %%
x+3
# Out:
# 6

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3

# %% [markdown]
# *hello<br>
# **hello**<br>
# ***hello***<br>

# %% [markdown]
# * list 1
#     * 1.1
# * list 2
# * list 3

# %% [markdown]
# 1. list 1
# 2. list 2
