# %%
data = {'Jordan': {"Gender": 'Male',"Score": {'Physics': 80, 'Math': 85, 'CS': 78, 'English': 50, 'Hitory':70}},
       'Divya':{"Gender": 'Female',"Score": {'Physics': 90, 'Math': 95, 'CS': 89, 'English': 92, 'Hitory':94}},
       'Jada':{"Gender": 'Female',"Score": {'Physics': 60, 'Math': 78, 'CS': 75, 'English': 69, 'Hitory':70}},
       'Kevin':{"Gender": 'Male',"Score": {'Physics': 56, 'Math': 60, 'CS': 70, 'English': 55, 'Hitory':58}},
       'Ahmed':{"Gender": 'Male',"Score": {'Physics': 45, 'Math': 40, 'CS': 35, 'English': 50, 'Hitory':58}},
       'Riya':{"Gender": 'Female',"Score": {'Physics': 80, 'Math': 79, 'CS': 86, 'English': 83, 'Hitory':87}}}
print(data)
# Out:
# {'Jordan': {'Gender': 'Male', 'Score': {'Physics': 80, 'Math': 85, 'CS': 78, 'English': 50, 'Hitory': 70}}, 'Divya': {'Gender': 'Female', 'Score': {'Physics': 90, 'Math': 95, 'CS': 89, 'English': 92, 'Hitory': 94}}, 'Jada': {'Gender': 'Female', 'Score': {'Physics': 60, 'Math': 78, 'CS': 75, 'English': 69, 'Hitory': 70}}, 'Kevin': {'Gender': 'Male', 'Score': {'Physics': 56, 'Math': 60, 'CS': 70, 'English': 55, 'Hitory': 58}}, 'Ahmed': {'Gender': 'Male', 'Score': {'Physics': 45, 'Math': 40, 'CS': 35, 'English': 50, 'Hitory': 58}}, 'Riya': {'Gender': 'Female', 'Score': {'Physics': 80, 'Math': 79, 'CS': 86, 'English': 83, 'Hitory': 87}}}
